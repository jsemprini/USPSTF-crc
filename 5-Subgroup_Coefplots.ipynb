# %%
install.packages("ggthemes")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
scale_colour_Publication <- function(...){
  library(scales)
  discrete_scale("colour","Publication",manual_pal(values = c("#386cb0","#fdb462","#7fc97f","#ef3b2c","#662506","#a6cee3","#fb9a99","#984ea3","#ffff33")), ...)

}

scale_fill_Publication <- function(...){
  library(scales)
  discrete_scale("fill","Publication",manual_pal(values = c("#386cb0","#fdb462","#7fc97f","#ef3b2c","#662506","#a6cee3","#fb9a99","#984ea3","#ffff33")), ...)

}

theme_Publication <- function(base_size=14, base_family="helvetica") {
  library(grid)
  library(ggthemes)
  (theme_foundation(base_size=base_size, base_family=base_family)
    + theme(plot.title = element_text(face = "bold",
                                      size = rel(1.2), hjust = 0.5),
            text = element_text(),
            panel.background = element_rect(colour = NA),
            plot.background = element_rect(colour = NA),
            panel.border = element_rect(colour = NA),
            axis.title = element_text(face = "bold",size = rel(1)),
            axis.title.y = element_text(angle=90,vjust =2),
            axis.title.x = element_text(vjust = -0.2),
            axis.text = element_text(),
            axis.line = element_line(colour="black"),
            axis.ticks = element_line(),
            panel.grid.major = element_line(colour="#f0f0f0"),
            panel.grid.minor = element_blank(),
            legend.key = element_rect(colour = NA),
            legend.position = "bottom",
            legend.direction = "horizontal",
            legend.key.size= unit(0.2, "cm"),
            legend.margin = unit(0, "cm"),
            legend.title = element_text(face="italic"),
            plot.margin=unit(c(10,5,5,5),"mm"),
            strip.background=element_rect(colour="#f0f0f0",fill="#f0f0f0"),
            strip.text = element_text(face="bold")
    ))

}

# %%
# Load necessary libraries
library(ggplot2)
library(dplyr)
library(ggthemes)

# Data import
data <- "
Age,outcome,est,se,low,high,N,avg
75-79,Blood Stool,-0.005,(0.004),-0.013,0.003,636548,0.338
75-79,Colonoscopy,-0.014,(0.005),-0.024,-0.004,640061,0.331
80+,Blood Stool,-0.001,(0.010),-0.021,0.019,659537,0.293
80+,Colonoscopy,-0.045,(0.005),-0.055,-0.035,661923,0.281
"

# Read data into a dataframe
df <- read.csv(text = data, header = TRUE)

# Convert columns to appropriate types
df <- df %>%
  mutate(Age = as.factor(Age),
         outcome = as.factor(outcome),
         est = as.numeric(est),
         low = as.numeric(low),
         high = as.numeric(high))

# Plotting
ggplot(df, aes(x = outcome, y = est, color = Age)) +
  geom_point(position = position_dodge(width = 0.5), size = 3) +
  geom_errorbar(aes(ymin = low, ymax = high),
                width = 0.2,
                position = position_dodge(width = 0.5)) +
  labs(title = "",
       x = "",
       y = "Estimate") +
  theme_Publication() +
  scale_y_continuous(limits = c(-0.075, 0.075)) +
  geom_hline(yintercept = 0, linetype = "dashed", color = "gray") +
  scale_fill_Publication() + scale_colour_Publication(, name = NULL)


#f4 - case

# Load necessary libraries
library(ggplot2)
library(dplyr)

# Data import
data <- "
outcome,Age,est,low,high
In Situ Dx,75-84,0,-0.00196,0.00196
Localized Dx,75-84,-0.008,-0.01192,-0.00408
Advanced Dx,75-84,0.01,0.00608,0.01392
Survival 1-year,75-84,-0.013,-0.01692,-0.00908
Survival 2-year,75-84,-0.015,-0.01892,-0.01108
Survival 5-year,75-84,-0.019,-0.02488,-0.01312
In Situ Dx,85+,0.005,0.00108,0.00892
Localized Dx,85+,-0.028,-0.03388,-0.02212
Advanced Dx,85+,0.026,0.02012,0.03188
Survival 1-year,85+,-0.029,-0.03488,-0.02312
Survival 2-year,85+,-0.029,-0.03488,-0.02312
Survival 5-year,85+,-0.027,-0.03288,-0.02112
"

# Read data into a dataframe
df <- read.csv(text = data, header = TRUE, sep = ",")

# Convert columns to appropriate types
df <- df %>%
  mutate(Age = as.factor(Age),
         outcome = as.factor(outcome),
         est = as.numeric(est),
         low = as.numeric(low),
         high = as.numeric(high))

# Plotting
ggplot(df, aes(x = outcome, y = est, color = Age)) +
  geom_point(position = position_dodge(width = 0.5), size = 3) +
  geom_errorbar(aes(ymin = low, ymax = high),
                width = 0.2,
                position = position_dodge(width = 0.5)) +
  labs(title = "",
       x = "",
       y = "Estimate") +
  theme_Publication() +
  scale_y_continuous(limits = c(-0.075, 0.075)) +
  geom_hline(yintercept = 0, linetype = "dashed", color = "gray") +
  scale_fill_Publication() + scale_colour_Publication(, name = NULL)



#f5 - pop

# Load necessary libraries
# Load necessary libraries
library(ggplot2)
library(dplyr)

# Data import
data <- "
Age,outcome,est,low,high
75-84,CRC-Incidence,-7.1,-13.2,-1.0
85+,CRC-Incidence,-20.6,-33.1,-8.2
75-84,Mortality-CRC,-1.20,-4.2,1.9
85+,Mortality-CRC,-10.00,-16.5,-3.6
75-84,Mortality-Other Cancer,16.00,4.5,27.5
85+,Mortality-Other Cancer,3.70,-16.9,24.3
75-84,Mortality (All-Cause),-65.90,-87.9,-43.8
85+,Mortality (All-Cause),-283.80,-385.3,-182.3
"

# Read data into a dataframe
df <- read.csv(text = data, header = TRUE, sep = ",")

# Display the dataframe to verify the import


# Convert columns to appropriate types
df <- df %>%
  mutate(Age = as.factor(Age),
         outcome = as.factor(outcome),
         est = as.numeric(est),
         low = as.numeric(low),
         high = as.numeric(high))

# Plotting
ggplot(df, aes(x = outcome, y = est, color = Age)) +
  geom_point(position = position_dodge(width = 0.5), size = 3) +
  geom_errorbar(aes(ymin = low, ymax = high),
                width = 0.2,
                position = position_dodge(width = 0.5)) +
  labs(title = "",
       x = "",
       y = "Estimate") +
  theme_Publication() +
  scale_y_continuous(limits = c(-400, 200)) +
  geom_hline(yintercept = 0, linetype = "dashed", color = "gray") +
  scale_fill_Publication() + scale_colour_Publication(, name = NULL)
# Out:
# Warning message:
# “`legend.margin` must be specified using `margin()`
# ℹ For the old behavior use `legend.spacing`”
# Warning message:
# “`legend.margin` must be specified using `margin()`
# ℹ For the old behavior use `legend.spacing`”
# plot without title
# Warning message:
# “`legend.margin` must be specified using `margin()`
# ℹ For the old behavior use `legend.spacing`”
# plot without title
# plot without title
